# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv(r"C:\Users\USER\AppData\Local\Temp\Temp1_archive.zip\Car details v3.csv")
df
# Out:
#                               name  year  selling_price  km_driven    fuel  \
# 0           Maruti Swift Dzire VDI  2014         450000     145500  Diesel
# 1     Skoda Rapid 1.5 TDI Ambition  2014         370000     120000  Diesel
# 2         Honda City 2017-2020 EXi  2006         158000     140000  Petrol
# 3        Hyundai i20 Sportz Diesel  2010         225000     127000  Diesel
# 4           Maruti Swift VXI BSIII  2007         130000     120000  Petrol
# ...                            ...   ...            ...        ...     ...
# 8123             Hyundai i20 Magna  2013         320000     110000  Petrol
# 8124         Hyundai Verna CRDi SX  2007         135000     119000  Diesel
# 8125        Maruti Swift Dzire ZDi  2009         382000     120000  Diesel
# 8126               Tata Indigo CR4  2013         290000      25000  Diesel
# 8127               Tata Indigo CR4  2013         290000      25000  Diesel
#
# ...

# %%
df.shape
# Out:
# (8128, 13)

# %%
df.columns
# Out:
# Index(['name', 'year', 'selling_price', 'km_driven', 'fuel', 'seller_type',
#        'transmission', 'owner', 'mileage', 'engine', 'max_power', 'torque',
#        'seats'],
#       dtype='object')

# %%
df.isnull().sum()
# Out:
# name               0
# year               0
# selling_price      0
# km_driven          0
# fuel               0
# seller_type        0
# transmission       0
# owner              0
# mileage          221
# engine           221
# max_power        215
# torque           222
# seats            221
# dtype: int64

# %%
df.dtypes
# Out:
# name              object
# year               int64
# selling_price      int64
# km_driven          int64
# fuel              object
# seller_type       object
# transmission      object
# owner             object
# mileage           object
# engine            object
# max_power         object
# torque            object
# seats            float64
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8128 entries, 0 to 8127
# Data columns (total 13 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   name           8128 non-null   object
#  1   year           8128 non-null   int64
#  2   selling_price  8128 non-null   int64
#  3   km_driven      8128 non-null   int64
#  4   fuel           8128 non-null   object
#  5   seller_type    8128 non-null   object
#  6   transmission   8128 non-null   object
#  7   owner          8128 non-null   object
#  8   mileage        7907 non-null   object
#  9   engine         7907 non-null   object
#  10  max_power      7913 non-null   object
#  11  torque         7906 non-null   object
#  12  seats          7907 non-null   float64
# dtypes: float64(1), int64(3), object(9)
# memory usage: 825.6+ KB

# %%
for i in df.columns:
    print(df[i].value_counts())
    print('\n')
# Out:
# Maruti Swift Dzire VDI                129
# Maruti Alto 800 LXI                    82
# Maruti Alto LXi                        71
# BMW X4 M Sport X xDrive20d             62
# Maruti Swift VDI                       61
#                                      ...
# Mahindra Bolero B2                      1
# Volvo XC60 Inscription D5 BSIV          1
# Hyundai i20 Active 1.2 SX with AVN      1
# Tata New Safari Dicor GX 4X2 BS IV      1
# BMW 3 Series 320d Prestige              1
# Name: name, Length: 2058, dtype: int64
#
#
# 2017    1018
# 2016     859
# 2018     807
# 2015     776
# 2013     670
# 2012     651
# 2014     621
# 2011     592
# 2019     583
# 2010     394
# 2009     246
# 2008     214
# 2007     183
# 2006     124
# 2005      97
# 2020      74
# 2004      62
# 2003      49
# 2002      27
# 2000      22
# 1999      18
# 1997      11
# 1998      10
# 2001      10
# 1994       3
# 1996       3
# 1995       2
# 1983       1
# 1991       1
# Name: year, dtype: int64
#
#
# ...

# %%
df["mileage"].tolist()
# Out:
# ['23.4 kmpl',
#  '21.14 kmpl',
#  '17.7 kmpl',
#  '23.0 kmpl',
#  '16.1 kmpl',
#  '20.14 kmpl',
#  '17.3 km/kg',
#  '16.1 kmpl',
#  '23.59 kmpl',
#  '20.0 kmpl',
#  '19.01 kmpl',
#  '17.3 kmpl',
#  '19.3 kmpl',
#  nan,
#  '18.9 kmpl',
#  '18.15 kmpl',
#  '24.52 kmpl',
#  '23.0 kmpl',
#  '19.7 kmpl',
#  '22.54 kmpl',
#  '21.0 kmpl',
#  '25.5 kmpl',
#  '26.59 kmpl',
#  '21.5 kmpl',
#  '20.3 kmpl',
#  '21.4 kmpl',
#  '24.7 kmpl',
#  '18.2 kmpl',
#  '18.9 kmpl',
#  '16.8 kmpl',
#  '24.3 kmpl',
#  nan,
#  '14.0 kmpl',
#  '18.6 kmpl',
#  '24.3 kmpl',
#  '33.44 km/kg',
#  '23.95 kmpl',
#  '17.0 kmpl',
#  '20.63 kmpl',
#  '13.93 kmpl',
#  '16.1 kmpl',
#  '16.0 kmpl',
#  '17.8 kmpl',
#  '16.8 kmpl',
#  '18.5 kmpl',
#  '24.3 kmpl',
#  '23.95 kmpl',
#  '12.55 kmpl',
#  '12.99 kmpl',
#  '14.8 kmpl',
#  '24.7 kmpl',
#  '13.5 kmpl',
#  '26.0 kmpl',
#  '20.65 kmpl',
#  '27.3 kmpl',
#  '11.36 kmpl',
#  '12.99 kmpl',
#  '17.68 kmpl',
#  '14.28 kmpl',
#  '18.53 kmpl',
#  '14.84 kmpl',
# ...

# %%
df['mileage'] = df["mileage"].str.strip("kmpl")

# %%
df['mileage'] = df["mileage"].str.strip("km/kg")

# %%
df["mileage"] = df["mileage"].astype(float)

# %%
df["mileage"] = df['mileage'].fillna(df['mileage'].mean())
df["mileage"]
# Out:
# 0       23.40
# 1       21.14
# 2       17.70
# 3       23.00
# 4       16.10
#         ...
# 8123    18.50
# 8124    16.80
# 8125    19.30
# 8126    23.57
# 8127    23.57
# Name: mileage, Length: 8128, dtype: float64

# %%
df["engine"].tolist()
# Out:
# ['1248 CC',
#  '1498 CC',
#  '1497 CC',
#  '1396 CC',
#  '1298 CC',
#  '1197 CC',
#  '1061 CC',
#  '796 CC',
#  '1364 CC',
#  '1399 CC',
#  '1461 CC',
#  '993 CC',
#  '1248 CC',
#  nan,
#  '1061 CC',
#  '1198 CC',
#  '1248 CC',
#  '1396 CC',
#  '796 CC',
#  '1396 CC',
#  '1461 CC',
#  '1498 CC',
#  '1248 CC',
#  '1248 CC',
#  '1199 CC',
#  '1197 CC',
#  '796 CC',
#  '1248 CC',
#  '1061 CC',
#  '796 CC',
#  '1248 CC',
#  nan,
#  '796 CC',
#  '1197 CC',
#  '1248 CC',
#  '796 CC',
#  '998 CC',
#  '1591 CC',
#  '1198 CC',
#  '2179 CC',
#  '796 CC',
#  '1368 CC',
#  '1497 CC',
#  '1497 CC',
#  '1197 CC',
#  '1248 CC',
#  '998 CC',
#  '2982 CC',
#  '2494 CC',
#  '2143 CC',
#  '1498 CC',
#  '2477 CC',
#  '1498 CC',
#  '1462 CC',
#  '1498 CC',
#  '2755 CC',
#  '2494 CC',
#  '1968 CC',
#  '1798 CC',
#  '1968 CC',
#  '2143 CC',
#  '1248 CC',
#  '1197 CC',
#  '1396 CC',
#  '1248 CC',
#  '1196 CC',
#  '1197 CC',
#  '1498 CC',
#  '1498 CC',
#  '998 CC',
#  '1498 CC',
#  '1248 CC',
#  '1248 CC',
# ...

# %%
df["engine"]=df["engine"].str.strip("CC")

# %%
df["engine"] =df["engine"].astype(float)

# %%
mean_value = df['engine'].mean()
df['engine'] = df['engine'].fillna(mean_value)

# %%
df["engine"] =df["engine"].astype(int)

# %%
df["engine"]
# Out:
# 0       1248
# 1       1498
# 2       1497
# 3       1396
# 4       1298
#         ...
# 8123    1197
# 8124    1493
# 8125    1248
# 8126    1396
# 8127    1396
# Name: engine, Length: 8128, dtype: int32

# %%
df["max_power"].tolist()
# Out:
# ['74 bhp',
#  '103.52 bhp',
#  '78 bhp',
#  '90 bhp',
#  '88.2 bhp',
#  '81.86 bhp',
#  '57.5 bhp',
#  '37 bhp',
#  '67.1 bhp',
#  '68.1 bhp',
#  '108.45 bhp',
#  '60 bhp',
#  '73.9 bhp',
#  nan,
#  '67 bhp',
#  '82 bhp',
#  '88.5 bhp',
#  '90 bhp',
#  '46.3 bhp',
#  '88.73 bhp',
#  '64.1 bhp',
#  '98.6 bhp',
#  '74 bhp',
#  '88.8 bhp',
#  '83.81 bhp',
#  '83.1 bhp',
#  '47.3 bhp',
#  '73.8 bhp',
#  '67 bhp',
#  '34.2 bhp',
#  '88.5 bhp',
#  nan,
#  '35 bhp',
#  '81.83 bhp',
#  '88.5 bhp',
#  '40.3 bhp',
#  '67.1 bhp',
#  '121.3 bhp',
#  '67 bhp',
#  '138.03 bhp',
#  '37 bhp',
#  '160.77 bhp',
#  '117.3 bhp',
#  '116.3 bhp',
#  '83.14 bhp',
#  '88.5 bhp',
#  '67.05 bhp',
#  '168.5 bhp',
#  '100 bhp',
#  '120.7 bhp',
#  '98.63 bhp',
#  '175.56 bhp',
#  '98.6 bhp',
#  '103.25 bhp',
#  '98.6 bhp',
#  '171.5 bhp',
#  '100.6 bhp',
#  '174.33 bhp',
#  '138.03 bhp',
#  '187.74 bhp',
#  '170 bhp',
#  '88.8 bhp',
#  '78.9 bhp',
#  '88.76 bhp',
#  '74 bhp',
#  '86.8 bhp',
#  '83.1 bhp',
# ...

# %%
df["max_power"] = df["max_power"].str.strip("bhp")

# %%
df["max_power"] = df["max_power"].replace(' ', np.nan)

# %%
df["max_power"] = df["max_power"].astype(float)

# %%
df["max_power"] = df["max_power"].fillna(df["max_power"].mean())

# %%
df["max_power"]
# Out:
# 0        74.00
# 1       103.52
# 2        78.00
# 3        90.00
# 4        88.20
#          ...
# 8123     82.85
# 8124    110.00
# 8125     73.90
# 8126     70.00
# 8127     70.00
# Name: max_power, Length: 8128, dtype: float64

# %%
df.drop("torque",inplace=True,axis=1) # if we remove unwanted things from the column for machine understanding or changing its data type, it will meaning less

# %%
df["seats"].tolist()
# Out:
# [5.0,
#  5.0,
#  5.0,
#  5.0,
#  5.0,
#  5.0,
#  5.0,
#  4.0,
#  5.0,
#  5.0,
#  5.0,
#  5.0,
#  5.0,
#  nan,
#  5.0,
#  5.0,
#  7.0,
#  5.0,
#  5.0,
#  5.0,
#  5.0,
#  5.0,
#  5.0,
#  5.0,
#  5.0,
#  5.0,
#  5.0,
#  7.0,
#  5.0,
#  8.0,
#  5.0,
#  nan,
#  5.0,
#  5.0,
#  5.0,
#  4.0,
#  5.0,
#  5.0,
#  5.0,
#  7.0,
#  4.0,
#  5.0,
#  5.0,
#  5.0,
#  5.0,
#  5.0,
#  5.0,
#  7.0,
#  7.0,
#  5.0,
#  5.0,
#  7.0,
#  5.0,
#  5.0,
#  5.0,
#  7.0,
#  7.0,
#  5.0,
#  5.0,
#  5.0,
#  5.0,
#  5.0,
#  5.0,
#  5.0,
#  5.0,
#  5.0,
#  5.0,
#  5.0,
#  5.0,
#  5.0,
#  5.0,
#  5.0,
#  5.0,
#  5.0,
#  5.0,
#  7.0,
#  5.0,
#  7.0,
#  nan,
#  5.0,
#  8.0,
#  5.0,
#  5.0,
#  5.0,
#  5.0,
#  5.0,
#  5.0,
#  nan,
#  5.0,
#  5.0,
#  5.0,
#  5.0,
#  5.0,
#  5.0,
#  5.0,
#  5.0,
#  5.0,
#  5.0,
#  5.0,
#  5.0,
#  5.0,
#  5.0,
#  5.0,
#  7.0,
#  5.0,
#  8.0,
#  5.0,
#  5.0,
#  5.0,
#  5.0,
#  7.0,
#  5.0,
#  5.0,
#  5.0,
#  5.0,
#  5.0,
#  5.0,
#  5.0,
#  5.0,
#  nan,
#  5.0,
#  5.0,
#  5.0,
#  5.0,
#  5.0,
# ...

# %%
df["seats"] = df["seats"].fillna(df["seats"].mean())

# %%
df["seats"] = df["seats"].astype(int)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8128 entries, 0 to 8127
# Data columns (total 12 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   name           8128 non-null   object
#  1   year           8128 non-null   int64
#  2   selling_price  8128 non-null   int64
#  3   km_driven      8128 non-null   int64
#  4   fuel           8128 non-null   object
#  5   seller_type    8128 non-null   object
#  6   transmission   8128 non-null   object
#  7   owner          8128 non-null   object
#  8   mileage        8128 non-null   float64
#  9   engine         8128 non-null   int32
#  10  max_power      8128 non-null   float64
#  11  seats          8128 non-null   int32
# dtypes: float64(2), int32(2), int64(3), object(5)
# memory usage: 698.6+ KB

# %%
# heatmap for checking the null value
sns.heatmap(df.isnull())
# Out:
# <AxesSubplot:>

# %%
df.describe()
# Out:
#               year  selling_price     km_driven      mileage       engine  \
# count  8128.000000   8.128000e+03  8.128000e+03  8128.000000  8128.000000
# mean   2013.804011   6.382718e+05  6.981951e+04    19.418783  1458.608022
# std       4.044249   8.062534e+05  5.655055e+04     3.981875   497.017515
# min    1983.000000   2.999900e+04  1.000000e+00     0.000000   624.000000
# 25%    2011.000000   2.549990e+05  3.500000e+04    16.800000  1197.000000
# 50%    2015.000000   4.500000e+05  6.000000e+04    19.418783  1248.000000
# 75%    2017.000000   6.750000e+05  9.800000e+04    22.277500  1582.000000
# max    2020.000000   1.000000e+07  2.360457e+06    42.000000  3604.000000
#
#          max_power        seats
# count  8128.000000  8128.000000
# mean     91.517919     5.405389
# std      35.343246     0.948874
# min       0.000000     2.000000
# 25%      68.100000     5.000000
# 50%      83.100000     5.000000
# 75%     101.250000     5.000000
# max     400.000000    14.000000

# %% [markdown]
# 1. There is no null value.
# 2. mean is greater than median (50%) so it is right skewed
# 4. There is hug different in maximum value and 75th percentilein some of the column like engine, max_power and so on. the outlier present in these columns

# %%
df.nunique().to_frame("no. of unique value")
# Out:
#                no. of unique value
# name                          2058
# year                            29
# selling_price                  677
# km_driven                      921
# fuel                             4
# seller_type                      3
# transmission                     2
# owner                            5
# mileage                        382
# engine                         122
# max_power                      320
# seats                            9

# %%
df.head(2)
# Out:
#                            name  year  selling_price  km_driven    fuel  \
# 0        Maruti Swift Dzire VDI  2014         450000     145500  Diesel
# 1  Skoda Rapid 1.5 TDI Ambition  2014         370000     120000  Diesel
#
#   seller_type transmission         owner  mileage  engine  max_power  seats
# 0  Individual       Manual   First Owner    23.40    1248      74.00      5
# 1  Individual       Manual  Second Owner    21.14    1498     103.52      5

# %%
sns.barplot(x=df["fuel"], y=df["selling_price"])
plt.xlabel('Fuel')
plt.ylabel('Selling Price')
plt.title('Relationship between Fuel and Price')
plt.show()

# %% [markdown]
# Diesel car has the highest price and LPG cars around 200000

# %%
plt.figure(figsize=(10,5))
sns.barplot(x=df["owner"], y=df["selling_price"])
plt.xlabel('owner')
plt.ylabel('Selling Price')
plt.title('Relationship between owner and Price')
plt.show()

# %%
sns.barplot(x=df["fuel"], y=df["mileage"])
plt.xlabel('Fuel')
plt.ylabel('mileage')
plt.title('Relationship between Fuel and mileage')
plt.show()

# %% [markdown]
# CNG cars has highest mileage compare to another fuel

# %%
plt.figure(figsize=(10,8))
sns.scatterplot(x="km_driven", y="selling_price",hue= 'fuel',data = df,palette='bright')
plt.xlabel('km_driven')
plt.ylabel('Selling Price')
plt.title('Relationship between km_driven and Price')
plt.show()

# %%
plt.figure(figsize=(10,8))
sns.scatterplot(x="year", y="selling_price",hue= 'fuel',data = df,palette='bright')
plt.xlabel('year')
plt.ylabel('Selling Price')
plt.title('Relationship between year,fuel and Price')
plt.show()

# %%
sns.pairplot(df, palette ='Dark2')

# %%
df_conti = df[["year","selling_price","km_driven","mileage","engine","max_power","seats"]]

# %%
#Let's see the how data is distributed 
plt.figure(figsize=(20,30),facecolor='white')
plotnumber=1
for column in df_conti:
    if plotnumber<=20:
        ax=plt.subplot(7,2,plotnumber)
        sns.distplot(df_conti[column])
        plt.xlabel(column,fontsize=10)
    plotnumber+=1
plt.tight_layout()

# %%
#Let's see the how data is distributed 
plt.figure(figsize=(20,30),facecolor='white')
plotnumber=1
for column in df_conti:
    if plotnumber<=20:
        ax=plt.subplot(7,2,plotnumber)
        sns.boxplot(df_conti[column],palette = 'Set2_r')
        plt.xlabel(column,fontsize=10)
    plotnumber+=1
plt.tight_layout()

# %% [markdown]
# Here, as compair to volume of data set year, seats and engine are consider as categorical column so do not handle outlier in that columns.

# %%
df.skew()
# Out:
# year             -1.072293
# selling_price     4.193533
# km_driven        11.170910
# mileage          -0.144647
# engine            1.151122
# max_power         1.643234
# seats             2.015507
# dtype: float64

# %% [markdown]
# Almost all the columns are skewed except mileage column but as we consider year, seats and engine are the categorical columns so do not need to handle skewness

# %%
# remove skewness using cuberoot
df["selling_price"] = np.cbrt(df["selling_price"])

# %%
df["km_driven"] = np.cbrt(df["km_driven"])

# %%
df["max_power"] = np.cbrt(df["max_power"])

# %%
df.skew()
# Out:
# year            -1.072293
# selling_price    1.535194
# km_driven       -0.057384
# mileage         -0.144647
# engine           1.151122
# max_power        0.343773
# seats            2.015507
# dtype: float64

# %%
# remove skewness using sqrt bcs it has skewness
df["selling_price"] = np.sqrt(df["selling_price"])

# %%
df.skew()
# Out:
# year            -1.072293
# selling_price    0.859973
# km_driven       -0.057384
# mileage         -0.144647
# engine           1.151122
# max_power        0.343773
# seats            2.015507
# dtype: float64

# %%
# remove skewness using log bcs it has skewness
df["selling_price"] = np.log(df["selling_price"])

# %%
df.skew()
# Out:
# year            -1.072293
# selling_price    0.223259
# km_driven       -0.057384
# mileage         -0.144647
# engine           1.151122
# max_power        0.343773
# seats            2.015507
# dtype: float64

# %% [markdown]
# finally, remove skewness from the respective columns and my threshold value is +/- 0.5

# %%
sns.distplot(df['selling_price'], color='m')
# Out:
# <AxesSubplot:xlabel='selling_price', ylabel='Density'>

# %%
sns.distplot(df['km_driven'], color='m')
# Out:
# <AxesSubplot:xlabel='km_driven', ylabel='Density'>

# %%
sns.distplot(df['max_power'], color='m')
# Out:
# <AxesSubplot:xlabel='max_power', ylabel='Density'>

# %% [markdown]
# The three variables are almost symmetrical

# %%
# encoding categorical column
from sklearn.preprocessing import OrdinalEncoder
OE = OrdinalEncoder()
for i in df.columns:
    if df[i].dtypes == 'object':
        df[i] = OE.fit_transform(df[i].values.reshape(-1,1))
df
# Out:
#         name  year  selling_price  km_driven  fuel  seller_type  transmission  \
# 0     1307.0  2014       2.169500  52.596196   1.0          1.0           1.0
# 1     1607.0  2014       2.136876  49.324241   1.0          1.0           1.0
# 2      385.0  2006       1.995058  51.924941   3.0          1.0           1.0
# 3      781.0  2010       2.053976  50.265257   1.0          1.0           1.0
# 4     1349.0  2007       1.962548  49.324241   3.0          1.0           1.0
# ...      ...   ...            ...        ...   ...          ...           ...
# 8123   771.0  2013       2.112679  47.914199   3.0          1.0           1.0
# 8124   656.0  2007       1.968838  49.186847   1.0          1.0           1.0
# 8125  1319.0  2009       2.142196  49.324241   1.0          1.0           1.0
# 8126  1699.0  2013       2.096273  29.240177   1.0          1.0           1.0
# 8127  1699.0  2013       2.096273  29.240177   1.0          1.0           1.0
#
# ...

# %%
# handle outliers
from scipy.stats import zscore

# %%
z = np.abs(df_conti)
z.shape
# Out:
# (8128, 7)

# %%
threshold = 3
print (np.where(z>3))
# Out:
# (array([   0,    0,    0, ..., 8127, 8127, 8127], dtype=int64), array([0, 1, 2, ..., 4, 5, 6], dtype=int64))

# %% [markdown]
# so here we can see almost columns has outlier, if we remove it we will lost whole data

# %%
# functions for detecting outlier(3 std)
def outlier_det(data_frame,feature_name):
    lower_limit=data_frame[feature_name].mean() - 3*data_frame[feature_name].std()
    upper_limit=data_frame[feature_name].mean() + 3*data_frame[feature_name].std()
    return (lower_limit,upper_limit)

# %%
outlier_det(df,"selling_price")
# Out:
# (1.7426678239792925, 2.5818016760506386)

# %%
df[(df["selling_price"]<1.742)|(df["selling_price"]>2.581)]
# Out:
#         name  year  selling_price  km_driven  fuel  seller_type  transmission  \
# 136   1474.0  2017       2.601212  33.322219   1.0          0.0           0.0
# 139     51.0  2019       2.595561  19.574338   1.0          0.0           0.0
# 148   1474.0  2017       2.596992  36.088261   1.0          0.0           0.0
# 170   2057.0  2017       2.686349  31.072325   3.0          1.0           0.0
# 384     51.0  2019       2.583652  19.574338   1.0          0.0           0.0
# ...      ...   ...            ...        ...   ...          ...           ...
# 7596    43.0  2018       2.596421  31.072325   1.0          1.0           0.0
# 7713  1474.0  2017       2.601212  33.322219   1.0          0.0           0.0
# 7872    51.0  2019       2.583652  19.574338   1.0          0.0           0.0
# 7873    51.0  2019       2.586710  20.408276   1.0          0.0           0.0
# 7930  2051.0  2019       2.586710  25.712816   1.0          1.0           0.0
#
# ...

# %%
outlier_det(df,"km_driven")
# Out:
# (8.971091581132804, 68.614074102442)

# %%
df[(df["km_driven"]<8.971)|(df["km_driven"]>68.614)]
# Out:
#         name  year  selling_price   km_driven  fuel  seller_type  \
# 998   1392.0  2012       2.050230   71.138064   3.0          1.0
# 1629  1948.0  2010       2.169500   69.382321   1.0          1.0
# 1810  1029.0  2012       2.187061  114.471424   1.0          1.0
# 2006  1935.0  2011       2.230788   72.112479   1.0          1.0
# 2272   855.0  2010       2.078073   72.431564   1.0          1.0
# 3486   760.0  2007       2.202946  133.147198   3.0          1.0
# 3508  1399.0  2010       2.029269   83.271382   3.0          1.0
# 3641  1408.0  2011       2.057638   79.370053   3.0          1.0
# 3852   619.0  2012       2.202946   69.104232   3.0          1.0
# 5106   943.0  2011       2.149870   78.024538   1.0          1.0
# 5189  1950.0  2013       2.254638   76.059049   1.0          1.0
# 5467  1951.0  2010       2.294036   75.243652   1.0          1.0
# 5813   619.0  2012       2.187061   69.104232   3.0          1.0
# ...

# %%
outlier_det(df,"mileage")
# Out:
# (7.473158168819369, 31.364408544219792)

# %%
df[(df["mileage"]<7.473)|(df["mileage"]>31.364)]
# Out:
#         name  year  selling_price  km_driven  fuel  seller_type  transmission  \
# 35    1078.0  2019       2.117808  21.544347   0.0          1.0           1.0
# 170   2057.0  2017       2.686349  31.072325   3.0          1.0           0.0
# 644   1686.0  2009       1.968838  30.687814   3.0          1.0           1.0
# 785    595.0  2009       1.949208  44.814047   3.0          1.0           1.0
# 1649   595.0  2008       1.926953  50.396842   3.0          1.0           1.0
# 1676  1462.0  2011       2.391023  47.914199   1.0          1.0           0.0
# 2137   807.0  2013       2.386048  40.163497   1.0          0.0           0.0
# 2312  1386.0  2013       2.084363  43.088694   0.0          1.0           1.0
# 2366   592.0  2010       1.934706  43.088694   3.0          1.0           1.0
# 2725   592.0  2013       2.020449  24.662121   3.0          1.0           1.0
# 3908  1077.0  2017       2.078073  40.615481   0.0          1.0           1.0
# ...

# %%
outlier_det(df,"max_power")
# Out:
# (2.8216698409995464, 6.060177356054152)

# %%
df[(df["max_power"]<2.821)|(df["max_power"]>6.060)]
# Out:
#         name  year  selling_price  km_driven  fuel  seller_type  transmission  \
# 134    803.0  2017       2.537750  25.712816   3.0          1.0           0.0
# 136   1474.0  2017       2.601212  33.322219   1.0          0.0           0.0
# 146     25.0  2015       2.465012  37.562858   1.0          0.0           0.0
# 148   1474.0  2017       2.596992  36.088261   1.0          0.0           0.0
# 170   2057.0  2017       2.686349  31.072325   3.0          1.0           0.0
# 575   1096.0  2011       2.038460  46.025820   3.0          1.0           1.0
# 576   1096.0  2011       2.038460  46.025820   3.0          1.0           1.0
# 1057    53.0  2013       2.522878  38.258624   1.0          0.0           0.0
# 1071    43.0  2018       2.601212  30.422179   1.0          0.0           0.0
# 1442  1308.0  2017       2.214364  34.547090   1.0          0.0           1.0
# 1443  1308.0  2017       2.214364  34.547090   1.0          0.0           1.0
# ...

# %% [markdown]
# when we using IQR method for removing outlier, comparitivly less but it has also lost data

# %%
# visualise correlation with heatmap
plt.figure(figsize=(20,10))
sns.heatmap(df.corr(),linewidths = 0.1, fmt = '.1g', linecolor='black',annot = True, cmap = 'Blues_r')
plt.yticks(rotation = 0);
plt.show()
